# %%
import os
import json

# %%
def read_jsonl(path):
    with open(path, "r") as f:
        data = [json.loads(ex) for ex in f]
    return data

# %%
pwd
# Out:
# '/lustre/hdd/LAS/weile-lab/mdrahman/MoECoder/src/data_processing'

# %%
formatted_data = read_jsonl("../../data/ex_tr_data/formatted_dataset.jsonl")

# %%
traced_data = read_jsonl("../../data/ex_tr_data/final_traced_dataset.jsonl")

# %%
print(traced_data[0].keys())
# Out:
# dict_keys(['user_prompt', 'assistant_prompt', 'input', 'answer', 'execution_trace', 'refcode', 'code', 'traced_info'])

# %%
for ex in traced_data[:2]:
    # print(ex.keys())
    # print(ex['user_prompt'])
    # print(ex['code'])
    # print(ex['refcode'])
    print(ex['refcode'])
    # print(ex['user_prompt'])
    # code = ex['user_prompt'].split("```")[1]
    # bindex = ex['user_prompt'].index(ex['refcode'])
    # eindex = bindex + len(ex['refcode'])

    # # print(ex['cod?e'])
    # lines = ex['code'].split("\n")
    # for i, line in enumerate(lines):
    #     print(i + 1, line)

    # dict = {}
    # for x in ex['traced_info']:
    #     dict[x['line_number']] = x
    #     print(x)

    # assert ex['refcode'] == ex['user_prompt'][bindex:eindex]
    # lines = code.split("\n")
    # for i, line in enumerate(lines):
    #     # info = dict.get(i, None)
    #     # # print(line, info['line'] if info else "" )
    #     # if info:
    #     #     assert info['line'] in line
    #     for i 
    # print(code)
    # print("---------")
    # print(ex['refcode'])
    # if ex['refcode'] not in ex['user_prompt']:
    #     print(code)
    #     print(ex['refcode'])
    #     print(len(code), len(ex['refcode']))
    #     print("----------------")
    # index = code.index(ex['refcode'])
    # print(index, len(ex['refcode']), len(code))
    # assert code[1:-1] == ex['refcode']
    # assert code[1:] == ex['refcode']
    # if ex['code'] != ex['refcode']:
    #     print(ex['code'])
    #     print("----------------------")
    #     print(ex['refcode'])
    #     break

    # ex['ref_code']
# Out:
# # import necessary packages
# from itertools import permutations
# from typing import List
#
# # all class and function definitions in the code file, if any
# def list_to_int(values: List) -> int:
#     return int("".join(map(str, values)))
#
# # main function
# def main_solution(n: int) -> int:
#     # all input arguments of the main_solution function should be json serializable (no self-defined objects, functions, np.array, set, tuple, etc.)
#     # if you need to invoke functions that require non-json serializable inputs, like those defined in the reference code file, you need to convert them (optional)
#     perms = list(permutations(range(1, n + 1)))
#     valid_perms = []
#
#     for i in perms:
#         for j in range(len(i) - 1):
#             a_len = len(i[: j + 1])
#             a = list_to_int(i[: j + 1])
#             if a_len > len(i) // 2:
#                 break
#             for k in range(len(i[j:]) - 2):
#                 b = list_to_int(i[j + 1 : j + k + 2])
# ...

# %%
traced_data[0]['refcode']
# Out:
# '# import necessary packages\nfrom itertools import permutations\nfrom typing import List\n\n# all class and function definitions in the code file, if any\ndef list_to_int(values: List) -> int:\n    return int("".join(map(str, values)))\n\n# main function\ndef main_solution(n: int) -> int:\n    # all input arguments of the main_solution function should be json serializable (no self-defined objects, functions, np.array, set, tuple, etc.)\n    # if you need to invoke functions that require non-json serializable inputs, like those defined in the reference code file, you need to convert them (optional)\n    perms = list(permutations(range(1, n + 1)))\n    valid_perms = []\n\n    for i in perms:\n        for j in range(len(i) - 1):\n            a_len = len(i[: j + 1])\n            a = list_to_int(i[: j + 1])\n            if a_len > len(i) // 2:\n                break\n            for k in range(len(i[j:]) - 2):\n                b = list_to_int(i[j + 1 : j + k + 2])\n                c = li
# ...
